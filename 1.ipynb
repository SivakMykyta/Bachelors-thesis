# %%
# !pip install ultralytics==8.0.35
# !pip install scikit-learn
# !pip install tensorflow==2.11.0
# !pip install scikit-image
# !pip install filterpy
# !pip install numpy

# %%
# !git clone https://github.com/computervisiondeveloper/deep_sort.git
# Out:
# Cloning into 'deep_sort'...

# %%
# !python main.py
# Out:
# 2024-04-01 22:58:59.023081: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Ultralytics YOLOv8.0.35  Python-3.8.7 torch-2.2.2+cpu CPU
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# 0: 384x640 35 persons, 2 birds, 80.8ms
# Speed: 1.0ms pre-process, 80.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 2024-04-01 22:58:59.349830: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:357] MLIR V1 optimization pass is not enabled
#
# 0: 384x640 34 persons, 3 birds, 99.7ms
# Speed: 1.0ms pre-process, 99.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 35 persons, 3 birds, 53.8ms
# ...
